# %%
import pandas as pd
import numpy as np

import sys
sys.path.append("..")

from toolbox_ml.eda.cat_regression import (get_features_cat_regression, plot_features_cat_regression)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       3
#       4 import sys
#       5 sys.path.append("..")
#       6
# ----> 7 from toolbox_ml.eda.cat_regression import (get_features_cat_regression, plot_features_cat_regression)
#
# File c:\Users\salit\OneDrive\Documentos\GitHub\DS-Online_willwalker7\Tools_ML_EDA\notebooks\..\toolbox_ml\eda\__init__.py:1
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
df_titanic = pd.read_csv("./data/titanic.csv")
